# %%
import os
from dotenv import load_dotenv

# Load the .env file
load_dotenv()

# Access the variables
neo4j_uri = os.getenv("NEO4J_URI")
neo4j_username = os.getenv("NEO4J_USERNAME")
neo4j_password = os.getenv("NEO4J_PASSWORD")
neo4j_database = os.getenv("NEO4J_DATABASE")

google_api_key = os.getenv("GOOGLE_API_KEY")
tavily_api_key = os.getenv("TAVILY_API_KEY")
groq_api_key = os.getenv("GROQ_API_KEY")

langsmith_endpoint = os.getenv("LANGSMITH_ENDPOINT")
langsmith_api_key = os.getenv("LANGSMITH_API_KEY")
langsmith_project = os.getenv("LANGSMITH_PROJECT")

# %% [markdown]
# # 🔐 Step 1: Environment Setup
#
# Load API keys and database credentials from `.env` file for:
# - **Neo4j** - Graph database for knowledge storage
# - **Google Gemini** - LLM for entity extraction
# - **LangSmith** - LLM observability and tracing
# - **Other APIs** - Tavily, Groq for extended functionality

# %% [markdown]
# # 🔬 Knowledge Graph RAG Pipeline for Medical Research
#
# This notebook demonstrates a **Knowledge Graph-based Retrieval Augmented Generation (GraphRAG)** system for medical research papers.
#
# ---
#
# ## 📋 Pipeline Overview
#
# 1. **📥 Load Data** - Import medical research papers from JSON files
# 2. **✂️ Split Documents** - Chunk papers into processable segments
# 3. **🧠 Extract Knowledge** - Use LLM to identify entities and relationships
# 4. **📊 Build Graph** - Store knowledge in Neo4j graph database
# 5. **🔍 Query & Visualize** - Interactive query-based subgraph exploration
#
# ---
#
# ## 🎯 Key Features
#
# - **Multi-section document parsing** with metadata preservation
# - **Automated entity/relationship extraction** using LLM transformers
# - **Graph-based retrieval** for more contextual answers
# - **Interactive visualization** using yFiles graph widgets
# - **Query-driven subgraph extraction** for focused exploration
#
# ---

# %%
from langchain_community.graphs import Neo4jGraph
graph = Neo4jGraph(neo4j_uri,
                neo4j_username,
                neo4j_password)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_1128\1695717956.py:2: LangChainDeprecationWarning: The class `Neo4jGraph` was deprecated in LangChain 0.3.8 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-neo4j package and should be used instead. To use it run `pip install -U :class:`~langchain-neo4j` and import as `from :class:`~langchain_neo4j import Neo4jGraph``.
#   graph = Neo4jGraph(neo4j_uri,

# %% [markdown]
# # 🗄️ Step 2: Connect to Neo4j Graph Database
#
# Initialize connection to Neo4j for storing and querying the knowledge graph.

# %%
from langchain.schema import Document
import json
from pathlib import Path

# Load all JSON files from the papers directory
def load_publication_documents(json_directory="papers", max_docs=1, include_sections=True):
    """
    Load publications from JSON files and convert to LangChain Documents
    
    Args:
        json_directory: Directory containing JSON files (default: "papers")
        max_docs: Maximum number of documents to load
        include_sections: If True, include structured sections; if False, use title+abstract only
    
    Returns:
        List of LangChain Document objects
    """
    documents = []
    json_files = list(Path(json_directory).glob("*.json"))[:max_docs]
    
    print(f"Found {len(json_files)} JSON files in '{json_directory}' folder")
    
    for json_file in json_files:
        try:
            with open(json_file, 'r', encoding='utf-8') as f:
                data = json.load(f)
                
                # Handle both single publication and list of publications
                publications = data if isinstance(data, list) else [data]
                
                for pub in publications:
                    # Extract fields
                    title = pub.get('title', 'No title')
                    abstract = pub.get('abstract', 'No abstract')
                    sections = pub.get('sections', {})
                    authors = pub.get('authors', [])
                    pub_id = pub.get('pmc_id') or pub.get('pmid', 'Unknown')
                    
                    # Create document content
                    content_parts = [f"Title: {title}", f"\nAbstract: {abstract}"]
                    
                    # Add structured sections if available and requested
                    if include_sections and sections:
                        content_parts.append("\n\nSections:")
                        for section_name, section_content in sections.items():
                            content_parts.append(f"\n\n## {section_name}\n{section_content}")
                    
                    content = ''.join(content_parts)
                    
                    # Create metadata with section names
                    metadata = {
                        'id': pub_id,
                        'title': title,
                        'authors': ', '.join(authors),
                        'source': str(json_file.name),
                        'num_authors': len(authors),
                        'sections': list(sections.keys()) if sections else [],
                        'num_sections': len(sections) if sections else 0
                    }
                    
                    # Create LangChain Document
                    doc = Document(page_content=content, metadata=metadata)
                    documents.append(doc)
                    
            print(f"✓ Loaded: {json_file.name}")
        
        except Exception as e:
            print(f"✗ Error loading {json_file.name}: {e}")
    
    print(f"\nTotal: {len(documents)} publication documents loaded")
    
    # Show section statistics
    all_sections = []
    for doc in documents:
        all_sections.extend(doc.metadata.get('sections', []))
    
    if all_sections:
        unique_sections = set(all_sections)
        print(f"Unique sections found: {len(unique_sections)}")
        print(f"Common sections: {', '.join(sorted(unique_sections)[:10])}")
    
    return documents

# Load documents with structured sections
raw_documents = load_publication_documents(json_directory="papers", max_docs=1, include_sections=True)

# Now you can use raw_documents with your GraphRAG pipeline
if raw_documents:
    print(f"\nFirst document preview:")
    print(f"ID: {raw_documents[0].metadata['id']}")
    print(f"Title: {raw_documents[0].metadata['title']}")
    print(f"Number of sections: {raw_documents[0].metadata['num_sections']}")
    print(f"Sections: {', '.join(raw_documents[0].metadata['sections'])}")
    print(f"Content length: {len(raw_documents[0].page_content)} characters")
# Out:
# Found 1 JSON files in 'papers' folder
# ✓ Loaded: PMC10114433.json
#
# Total: 1 publication documents loaded
# Unique sections found: 28
# Common sections: Acknowledgements, Associated Data, Availability of data and materials, Background, Clinicopathological factors of postoperative liver dysfunction, Competing interests, Conclusions, Contributor Information, Data Availability Statement, Discussion
#
# First document preview:
# ID: PMC10114433
# Title: Postoperative liver dysfunction is associated with poor long-term outcomes in patients with colorectal cancer: a retrospective cohort study - PMC
# Number of sections: 28
# Sections: Eigo Otsuji, Background, Methods, Results, Conclusions, Patients, Fig. 1., Risk factor identification and prognostic impact, Table 1., Table 2., Table 3., Fig. 2., Table 4., Fatty liver assessment, Statistical analysis, Clinicopathological factors of postoperative liver dysfunction, Risk factors influencing the severity of postoperative liver dysfunction, Hepatobiliary enzyme abnormalities, Prognostic impact of postoperative liver dysfunction in Stage III CRC, Discussion, Acknowledgements, Availability of data and materials, Ethical approval and consent to participate, Competing interests, Footnotes, Contributor Information, Associated Data, Data Availability Statement
# Content length: 21699 characters

# %% [markdown]
# # 📄 Step 3: Load Medical Research Papers
#
# Load publication JSON files from the `papers/` directory and convert them to LangChain Documents.
#
# **Features:**
# - 📚 Parses structured sections (Background, Methods, Results, etc.)
# - 🏷️ Extracts metadata (authors, IDs, section names)
# - 🔢 Configurable document limit and section inclusion
# - 📊 Statistics on sections and content

# %%
from langchain.text_splitter import TokenTextSplitter

text_splitter = TokenTextSplitter(chunk_size=512, chunk_overlap=24)
documents = text_splitter.split_documents(raw_documents)

# %% [markdown]
# # ✂️ Step 4: Split Documents into Chunks
#
# Split large documents into smaller chunks for better LLM processing.
#
# **Parameters:**
# - `chunk_size=512` - Maximum tokens per chunk
# - `chunk_overlap=24` - Overlap between chunks to preserve context

# %%
len(raw_documents)
# Out:
# 1

# %%
raw_documents[0].page_content
# Out:
# "Title: Postoperative liver dysfunction is associated with poor long-term outcomes in patients with colorectal cancer: a retrospective cohort study - PMC\nAbstract: BackgroundPostoperative hepatobiliary enzyme abnormalities often present as postoperative liver dysfunction in patients with colorectal cancer. This study aimed to clarify the risk factors of postoperative liver dysfunction and its prognostic impact following colorectal cancer surgery. MethodsWe retrospectively analyzed data from 360 consecutive patients who underwent radical resection for Stage I–IV colorectal cancer between 2015 and 2019. A subset of 249 patients with Stage III colorectal cancer were examined to assess the prognostic impact of liver dysfunction. ResultsForty-eight (13.3%) colorectal cancer patients (Stages I–IV) developed postoperative liver dysfunction (Common Terminology Criteria for Adverse Events version 5.0 CTCAE v5.0\u2009≥\u2009Grade 2). Univariate and multivariate analyses identified the liver-to-spleen ratio on preoperative plain computed tomography (L/S ratio;P=\u20090.002, Odds ratio 2.66) as an independent risk factor for liver dysfunction. Patients with postoperative liver dysfunction showed significantly poorer disease-free survival than patients without liver dysfunction (P<\u20090.001). Univariate and multivariate analyses using Cox’s proportional hazards model revealed that postoperative liver dysfunction independently was a poor prognostic factor (P=\u20090.001, Hazard ratio 2.75, 95% CI: 1.54–4.73). ConclusionsPostoperative liver dysfunction was associated with poor long-term outcomes in patients with Stage III colorectal cancer. A low liver-to-spleen ratio on preoperative plain computed tomography images was an independent risk factor of postoperative liver dysfunction. Supplementary InformationThe online version contains supplementary material available at 10.1186/s12876-023-02762-y. Keywords:Colorectal cancer, Postoperative complication, Liver dysfunction, Prognosis, Risk factor, Fatty liver\n\nSections:\n\n## Eigo Otsuji\nCorresponding author. Received 2022 Nov 21; Accepted 2023 Apr 9; Collection date 2023. Open AccessThis article is licensed under a Creative Commons Attribution 4.0 International License, which permits use, sharing, adaptation, distribution and reproduction in any medium or format, as long as you give appropriate credit to the original author(s) and the source, provide a link to the Creative Commons licence, and indicate if changes were made. The images or other third party material in this article are included in the article's Creative Commons licence, unless indicated otherwise in a credit line to the material. If material is not included in the article's Creative Commons licence and your intended use is not permitted by statutory regulation or exceeds the permitted use, you will need to obtain permission directly from the copyright holder. To view a copy of this licence, visithttp://creativecommons.org/licenses/by/4.0/. The Creative Commons Public Domain Dedication waiver (http://creativecommons.org/publicdomain/zero/1.0/) applies to the data made available in this article, unless otherwise stated in a credit line to the data.\n\n## Background\nColorectal cancer (CRC) is the third most commonly occurring cancer in the world [1]. Despite recent advances in surgical procedures and chemotherapy, tumor recurrence is often observed in CRC patients after curative resection, leading to a high mortality rate. Therefore, it is important to identify reliable predictors of patients at high risk of tumor recurrence. The association between postoperative adverse events and poor long-term outcomes has been reported in various surgical fields [2–4]. In CRC, postoperative complications were associated with tumor recurrence and poor outcomes [5]. Therefore, postoperative liver dysfunction may also be associated with the deterioration of long-term outcomes. Although postoperative hepatobiliary enzyme abnormalities often p ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash" )
# from langchain_ollama import ChatOllama
# llm_ollama = ChatOllama(model="llama3.1:70b", temperature=0)

# %% [markdown]
# # 🤖 Step 5: Initialize LLM
#
# Set up **Google Gemini 2.5 Flash** for entity extraction and relationship identification.
#
# > **Note:** Can switch to local Ollama models (commented out) for privacy/cost considerations.

# %%
from langchain_experimental.graph_transformers import LLMGraphTransformer
llm_transformer = LLMGraphTransformer(llm)

# %% [markdown]
# # 🔄 Step 6: Create Graph Transformer
#
# Initialize the **LLMGraphTransformer** to automatically extract:
# - 🏷️ **Entities** (people, concepts, diseases, treatments)
# - 🔗 **Relationships** (causes, treats, associates with)
#
# This converts unstructured text into structured knowledge graph format.

# %%
graph_documents = llm_transformer.convert_to_graph_documents(documents)

# %% [markdown]
# # 🧬 Step 7: Extract Graph Documents
#
# Transform text chunks into graph documents containing nodes (entities) and edges (relationships).
#
# > ⏱️ **Note:** This step may take a few minutes depending on document size and LLM speed.

# %%
graph_documents
# Out:
# [GraphDocument(nodes=[Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Poor Long-Term Outcomes', type='Outcome', properties={}), Node(id='Colorectal Cancer', type='Disease', properties={}), Node(id='Study', type='Study', properties={}), Node(id='Postoperative Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), Node(id='Colorectal Cancer Surgery', type='Procedure', properties={}), Node(id='Radical Resection', type='Procedure', properties={}), Node(id='Stage I–Iv Colorectal Cancer', type='Disease', properties={}), Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), Node(id='Ctcae V5.0', type='Standard', properties={}), Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), Node(id='Preoperative Plain Computed Tomography', type='Medical test', properties={}), Node(id='Disease-Free Survival', type='Outcome', properties={}), Node(id='Eigo Otsuji', type='Person', properties={}), Node(id='360 Patients', type='Patient group', properties={}), Node(id='249 Patients With Stage Iii Colorectal Cancer', type='Patient group', properties={}), Node(id='Low Liver-To-Spleen Ratio', type='Measurement', properties={})], relationships=[Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Poor Long-Term Outcomes', type='Outcome', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Study', type='Study', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='INVESTIGATES', properties={}), Relationship(source=Node(id='Study', type='Study', properties={}), target=Node(id='Colorectal Cancer', type='Disease', properties={}), type='INVESTIGATES', properties={}), Relationship(source=Node(id='Postoperative Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='PRESENTS_AS', properties={}), Relationship(source=Node(id='Colorectal Cancer', type='Disease', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='HAS_COMPLICATION', properties={}), Relationship(source=Node(id='Colorectal Cancer Surgery', type='Procedure', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='HAS_COMPLICATION', properties={}), Relationship(source=Node(id='360 Patients', type='Patient group', properties={}), target=Node(id='Radical Resection', type='Procedure', properties={}), type='UNDERWENT', properties={}), Relationship(source=Node(id='Radical Resection', type='Procedure', properties={}), target=Node(id='Stage I–Iv Colorectal Cancer', type='Disease', properties={}), type='FOR', properties={}), Relationship(source=Node(id='Study', type='Study', properties={}), target=Node(id='360 Patients', type='Patient group', properties={}), type='INCLUDED', properties={}), Relationship(source=Node(id='249 Patients With Stage Iii Colorectal Cancer', type='Patient group', properties={}), target=Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), type='HAS_DISEASE', properties={}), Relationship(source=Node(id='Study', type='Study', properties={}), target=Node(id='249 Patients With Stage Iii Colorectal Cancer', type='Patient group', properties={}), type='EXAMINED', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Ctcae V5.0', type='Standard', properties={}), type='GRADED_BY', properties={}), Relationship(source=Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), target=Node(id='Preoperative Plain Computed Tomography', type='Medical test', properties={}), type='MEASURED_BY', properties={}), Relationship(source=Node(id='Low Liver-To-Spleen Ratio', type='Measurement', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', pro ...
#  GraphDocument(nodes=[Node(id='International License', type='License', properties={}), Node(id='Creative Commons Licence', type='License', properties={}), Node(id='Creative Commons Public Domain Dedication Waiver', type='Waiver', properties={}), Node(id='Http://Creativecommons.Org/Licenses/By/4.0/', type='Url', properties={}), Node(id='Http://Creativecommons.Org/Publicdomain/Zero/1.0/', type='Url', properties={}), Node(id='Colorectal Cancer', type='Disease', properties={}), Node(id='Cancer', type='Disease', properties={}), Node(id='Tumor Recurrence', type='Medical condition', properties={}), Node(id='Surgical Procedures', type='Treatment', properties={}), Node(id='Chemotherapy', type='Treatment', properties={}), Node(id='Patients With Colorectal Cancer', type='Patient group', properties={}), Node(id='Postoperative Adverse Events', type='Medical condition', properties={}), Node(id='Long-Term Outcomes', type='Outcome', properties={}), Node(id='Postoperative Complications', type='Medical condition', properties={}), Node(id='Postoperative Liver Dysfunction', type='Medical condition', properties={}), Node(id='Postoperative Hepatobiliary Enzyme Abnormalities', type='Medical condition', properties={}), Node(id='Prognostic Impact', type='Concept', properties={}), Node(id='Radical Resection', type='Treatment', properties={}), Node(id='High Mortality Rate', type='Outcome', properties={}), Node(id='Poor Outcomes', type='Outcome', properties={}), Node(id='Poor Prognosis', type='Outcome', properties={}), Node(id='360 Consecutive Patients', type='Patient group', properties={}), Node(id='Stage I-Iv Colorectal Cancer', type='Disease stage', properties={}), Node(id='2015', type='Year', properties={}), Node(id='2019', type='Year', properties={}), Node(id='249 Patients', type='Patient group', properties={}), Node(id='Stage Iii Colorectal Cancer', type='Disease stage', properties={}), Node(id='Study', type='Research', properties={}), Node(id='Risk Factors', type='Concept', properties={}), Node(id='Curative Resection', type='Treatment', properties={}), Node(id='Use', type='Concept', properties={}), Node(id='Sharing', type='Concept', properties={}), Node(id='Adaptation', type='Concept', properties={}), Node(id='Distribution', type='Concept', properties={}), Node(id='Reproduction', type='Concept', properties={}), Node(id='Deterioration Of Long-Term Outcomes', type='Outcome', properties={})], relationships=[Relationship(source=Node(id='Creative Commons Licence', type='License', properties={}), target=Node(id='Http://Creativecommons.Org/Licenses/By/4.0/', type='Url', properties={}), type='HAS_URL', properties={}), Relationship(source=Node(id='Creative Commons Public Domain Dedication Waiver', type='Waiver', properties={}), target=Node(id='Http://Creativecommons.Org/Publicdomain/Zero/1.0/', type='Url', properties={}), type='HAS_URL', properties={}), Relationship(source=Node(id='International License', type='License', properties={}), target=Node(id='Use', type='Concept', properties={}), type='PERMITS', properties={}), Relationship(source=Node(id='International License', type='License', properties={}), target=Node(id='Sharing', type='Concept', properties={}), type='PERMITS', properties={}), Relationship(source=Node(id='International License', type='License', properties={}), target=Node(id='Adaptation', type='Concept', properties={}), type='PERMITS', properties={}), Relationship(source=Node(id='International License', type='License', properties={}), target=Node(id='Distribution', type='Concept', properties={}), type='PERMITS', properties={}), Relationship(source=Node(id='International License', type='License', properties={}), target=Node(id='Reproduction', type='Concept', properties={}), type='PERMITS', properties={}), Relationship(source=Node(id='Colorectal Cancer', type='Disease', properties={}), target=Node(id='Cancer', type='Disease', properties={}), type='IS_A_TYPE_OF', properties={}), Relationship(source=Node(id='Tumor Recurrence', type='Medical con ...
#  GraphDocument(nodes=[Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), Node(id='Liver Dysfunction', type='Condition', properties={}), Node(id='Colorectal Cancer', type='Disease', properties={}), Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Ctcae V5.0', type='Standard', properties={}), Node(id='L/S Ratio', type='Ratio', properties={}), Node(id='Disease-Free Survival', type='Outcome', properties={}), Node(id='Poor Prognostic Factor', type='Factor', properties={}), Node(id='Poor Prognosis', type='Outcome', properties={}), Node(id='Poor Long-Term Outcomes', type='Outcome', properties={}), Node(id='Low L/S Ratio', type='Ratio', properties={}), Node(id='Preoperative Interventions', type='Intervention', properties={}), Node(id='Fatty Liver', type='Condition', properties={}), Node(id='Prognosis For Colorectal Cancer', type='Outcome', properties={}), Node(id='Kyoto Prefectural University Of Medicine', type='Organization', properties={}), Node(id='Declaration Of Helsinki', type='Standard', properties={}), Node(id='Ethical Review Board Of The Kyoto Prefectural University Of Medicine', type='Organization', properties={}), Node(id='Experimental Protocol', type='Protocol', properties={}), Node(id='Patients', type='Group', properties={}), Node(id='Surgical Resection With Lymph Node Dissection', type='Procedure', properties={}), Node(id='Preoperative Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), Node(id='Distant Metastasis', type='Condition', properties={}), Node(id='Liver Metastasis', type='Condition', properties={}), Node(id='Other Cancers', type='Disease', properties={}), Node(id='Colectomy With Combined Resection', type='Procedure', properties={}), Node(id='Emergency Operation', type='Procedure', properties={})], relationships=[Relationship(source=Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), target=Node(id='Liver Dysfunction', type='Condition', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Colorectal Cancer', type='Disease', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='DEVELOPED_CONDITION', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Ctcae V5.0', type='Standard', properties={}), type='GRADED_BY', properties={}), Relationship(source=Node(id='L/S Ratio', type='Ratio', properties={}), target=Node(id='Liver Dysfunction', type='Condition', properties={}), type='IS_RISK_FACTOR_FOR', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Disease-Free Survival', type='Outcome', properties={}), type='IMPACTS', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Poor Prognostic Factor', type='Factor', properties={}), type='IS_A', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Poor Prognosis', type='Outcome', properties={}), type='LEADS_TO', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Poor Long-Term Outcomes', type='Outcome', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Poor Long-Term Outcomes', type='Outcome', properties={}), target=Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), type='AFFECTS_PATIENTS_WITH', properties={}), Relationship(source=Node(id='Low L/S Ratio', type='Ratio', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Preoperative Interventions', type='Intervention', properties={}), target=Node(id='Fatty Liver', type='Condition', properties={}), type= ...
#  GraphDocument(nodes=[Node(id='Distant Metastasis', type='Condition', properties={}), Node(id='Liver Metastasis', type='Condition', properties={}), Node(id='360 Patients', type='Patient group', properties={}), Node(id='Study', type='Study', properties={}), Node(id='Patient Characteristics', type='Data', properties={}), Node(id='Pathological Findings', type='Data', properties={}), Node(id='Surgical Findings', type='Data', properties={}), Node(id='Postoperative Clinical Courses', type='Data', properties={}), Node(id='Medical Records', type='Source', properties={}), Node(id='Databases', type='Source', properties={}), Node(id='Institution', type='Institution', properties={}), Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Prognostic Effect', type='Effect', properties={}), Node(id='Analyzed Data', type='Data', properties={}), Node(id='249 Patients', type='Patient group', properties={}), Node(id='Radical Resection', type='Procedure', properties={}), Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={}), Node(id='Colorectal Adenocarcinoma', type='Disease', properties={}), Node(id='Preoperative Diagnosis', type='Diagnosis', properties={}), Node(id='Endoscopy', type='Procedure', properties={}), Node(id='Biopsy', type='Procedure', properties={}), Node(id='Patients With Lower Rectal Cancer', type='Patient group', properties={}), Node(id='Lower Rectal Cancer', type='Disease', properties={}), Node(id='T3 Or Deeper', type='Stage', properties={}), Node(id='Neoadjuvant Chemoradiotherapies', type='Therapy', properties={}), Node(id='Radical Surgery', type='Procedure', properties={}), Node(id='Colorectal Resection', type='Procedure', properties={}), Node(id='Lymph Node Dissection', type='Procedure', properties={}), Node(id='Japanese Society For Cancer Of The Colon And Rectum', type='Organization', properties={}), Node(id='Guidelines', type='Document', properties={}), Node(id='Surgical Oncologists', type='Profession', properties={}), Node(id='Surgical Procedures', type='Procedure', properties={}), Node(id='Preoperative Multidisciplinary Conference', type='Event', properties={}), Node(id='Tumor Stages', type='Stage', properties={}), Node(id='Uicc Tnm Classification System (8Th Ed.)', type='Classification system', properties={}), Node(id='Macroscopic Cancer Types', type='Type', properties={}), Node(id='Histological Cancer Types', type='Type', properties={}), Node(id='Japanese Classification Of Colorectal Carcinoma (8Th Ed.)', type='Classification system', properties={}), Node(id='Physical Examinations', type='Test', properties={}), Node(id='Blood Tests', type='Test', properties={}), Node(id='Tumor Markers', type='Marker', properties={}), Node(id='Carcinoembryonic Antigen (Cea)', type='Marker', properties={}), Node(id='Computed Tomography (Ct)', type='Test', properties={}), Node(id='Colonoscopies', type='Test', properties={}), Node(id='Surgery', type='Procedure', properties={}), Node(id='Tumor Recurrence', type='Condition', properties={}), Node(id='Radiography', type='Procedure', properties={}), Node(id='Treatments', type='Therapy', properties={}), Node(id='Clinical Factors', type='Factor', properties={}), Node(id='Crc Patients', type='Patient group', properties={}), Node(id='Aspartate Transaminase (Ast)', type='Enzyme', properties={}), Node(id='Alanine Aminotransferase (Alt)', type='Enzyme', properties={}), Node(id='Alkaline Phosphatase (Alp)', type='Enzyme', properties={}), Node(id='Gamma-Glutamyl Transpeptidase (Ggt)', type='Enzyme', properties={}), Node(id='Total Bilirubin (T-Bil)', type='Substance', properties={}), Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), Node(id='Ctcae V5.0 Diagnostic Criteria', type='Criteria', properties={}), Node(id='Council For International Organizations Of Medical Sciences', type='Organization', properties={}), Node(id='Serum Hepatobiliary Enzyme Levels', type='Measurement', properties={}), Node(id='Preoperatively', type='Time p ...
#  GraphDocument(nodes=[Node(id='Serum Liver Enzyme Levels', type='Measurement', properties={}), Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Severe Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Hepatobiliary Enzyme Abnormalities Of Grade 2 Or Higher', type='Definition', properties={}), Node(id='Hepatobiliary Enzyme Abnormalities Of Grade 3 Or Higher', type='Definition', properties={}), Node(id='Clinicopathological Factors', type='Factor', properties={}), Node(id='Independent Risk Factors', type='Factor', properties={}), Node(id='Univariate Logistic Analysis', type='Analysis method', properties={}), Node(id='Multivariate Logistic Analysis', type='Analysis method', properties={}), Node(id='Putative Risk Factors', type='Factor', properties={}), Node(id='Features Of Liver Dysfunction', type='Characteristic', properties={}), Node(id='Overall Survival Curves', type='Data representation', properties={}), Node(id='Disease-Free Survival Curves', type='Data representation', properties={}), Node(id='Patients With Postoperative Liver Dysfunction', type='Patient group', properties={}), Node(id='Patients Without Postoperative Liver Dysfunction', type='Patient group', properties={}), Node(id='Radical Resection For Stage Iii Colorectal Cancer', type='Procedure', properties={}), Node(id='Prognostic Effects', type='Effect', properties={}), Node(id='Univariate Analysis With Cox’S Proportional Hazard Ratios', type='Analysis method', properties={}), Node(id='Multivariate Analysis With Cox’S Proportional Hazard Ratios', type='Analysis method', properties={}), Node(id='Clinical Factors', type='Factor', properties={}), Node(id='Non-Severe Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Ctcae Grade ≥ 3', type='Severity definition', properties={}), Node(id='Ctcae Grade 2', type='Severity definition', properties={}), Node(id='Chi Squared Test', type='Statistical test', properties={}), Node(id='Fisher’S Exact Probability Tests', type='Statistical test', properties={}), Node(id='Profile Of Postoperative Liver Dysfunction', type='Characteristic', properties={}), Node(id='Ast Aspartate Transaminase', type='Enzyme', properties={}), Node(id='Alt Alanine Aminotransferase', type='Enzyme', properties={}), Node(id='Alp Alkaline Phosphatase', type='Enzyme', properties={}), Node(id='Ggt Gamma-Glutamyl Transpeptidase', type='Enzyme', properties={}), Node(id='T-Bil Total Bilirubin', type='Biomarker', properties={}), Node(id='Disease-Free Survival After Surgery For Stage Iii Colorectal Cancer', type='Outcome', properties={}), Node(id='Kaplan-Meier Method', type='Statistical method', properties={}), Node(id='Log-Rank Test', type='Statistical test', properties={}), Node(id="Cox'S Proportional Hazard Model", type='Statistical model', properties={}), Node(id='Ci Confidence Interval', type='Statistical measure', properties={}), Node(id='Fatty Liver', type='Condition', properties={}), Node(id='Preoperative Ct Images', type='Medical imaging', properties={}), Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), Node(id='Significance', type='Characteristic', properties={})], relationships=[Relationship(source=Node(id='Serum Liver Enzyme Levels', type='Measurement', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='MEASURED_FOR_ASSESSMENT_OF', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Hepatobiliary Enzyme Abnormalities Of Grade 2 Or Higher', type='Definition', properties={}), type='DEFINED_BY', properties={}), Relationship(source=Node(id='Severe Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Hepatobiliary Enzyme Abnormalities Of Grade 3 Or Higher', type='Definition', properties={}), type='DEFINED_BY', properties={}), Relationship(source=Node(id='Clinicopathological Factors', type='Factor ...
#  GraphDocument(nodes=[Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), Node(id='Preoperative Ct Images', type='Image', properties={}), Node(id='Hounsfield Unit Values', type='Measurement', properties={}), Node(id='Regions Of Interest', type='Region', properties={}), Node(id='Liver', type='Organ', properties={}), Node(id='Spleen', type='Organ', properties={}), Node(id='Jmp Version 10', type='Software', properties={}), Node(id='Asa Institute', type='Organization', properties={}), Node(id='Cary, Nc', type='Location', properties={}), Node(id='Chi-Squared Test', type='Statistical test', properties={}), Node(id='Fisher’S Exact Probability Test', type='Statistical test', properties={}), Node(id='Student’S T-Test', type='Statistical test', properties={}), Node(id='Mann–Whitneyu-Test', type='Statistical test', properties={}), Node(id='Kaplan–Meier Method', type='Statistical method', properties={}), Node(id='Log-Rank Test', type='Statistical test', properties={}), Node(id='Univariate Survival Analysis', type='Analysis', properties={}), Node(id='Multivariate Survival Analysis', type='Analysis', properties={}), Node(id='Likelihood Ratio Test', type='Statistical test', properties={}), Node(id='Stratified Cox Proportional Hazards Model', type='Statistical model', properties={}), Node(id='Postoperative Liver Dysfunction', type='Medical condition', properties={}), Node(id='Low-Molecular-Weight Heparin', type='Medication', properties={}), Node(id='Chronic Liver Disease', type='Medical condition', properties={}), Node(id='Severe Postoperative Liver Dysfunction', type='Medical condition', properties={}), Node(id='P< 0.05', type='Statistical threshold', properties={}), Node(id='Categorical Variables', type='Data type', properties={}), Node(id='Unpaired Continuous Data', type='Data type', properties={}), Node(id='Survival Curves', type='Data representation', properties={}), Node(id='Statistical Differences', type='Concept', properties={}), Node(id='48 Patients', type='Patient group', properties={}), Node(id='Grade 2', type='Severity grade', properties={}), Node(id='Grade 3', type='Severity grade', properties={}), Node(id='1.268', type='Value', properties={}), Node(id='2-Cm Diameter', type='Measurement', properties={}), Node(id='Statistical Analysis', type='Analysis', properties={}), Node(id='10 Patients', type='Patient group', properties={}), Node(id='38 Patients', type='Patient group', properties={})], relationships=[Relationship(source=Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), target=Node(id='Preoperative Ct Images', type='Image', properties={}), type='CALCULATED_FROM', properties={}), Relationship(source=Node(id='Hounsfield Unit Values', type='Measurement', properties={}), target=Node(id='Preoperative Ct Images', type='Image', properties={}), type='MEASURED_IN', properties={}), Relationship(source=Node(id='Regions Of Interest', type='Region', properties={}), target=Node(id='Liver', type='Organ', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Regions Of Interest', type='Region', properties={}), target=Node(id='Spleen', type='Organ', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Liver-To-Spleen Ratio', type='Measurement', properties={}), target=Node(id='Hounsfield Unit Values', type='Measurement', properties={}), type='CALCULATED_FROM', properties={}), Relationship(source=Node(id='Statistical Analysis', type='Analysis', properties={}), target=Node(id='Jmp Version 10', type='Software', properties={}), type='PERFORMED_USING', properties={}), Relationship(source=Node(id='Jmp Version 10', type='Software', properties={}), target=Node(id='Asa Institute', type='Organization', properties={}), type='DEVELOPED_BY', properties={}), Relationship(source=Node(id='Asa Institute', type='Organization', properties={}), target=Node(id='Cary, Nc', type='Location', properties={}), type='LOCATED_IN', properties={}), Relationship(source=Node(id='Chi-Squared ...
#  GraphDocument(nodes=[Node(id='Severe Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Lower Albumin-Bilirubin Scores', type='Score', properties={}), Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), Node(id='Hepatitis Virus Infection', type='Disease', properties={}), Node(id='Alcohol-Induced Liver Injury', type='Disease', properties={}), Node(id='Drug-Induced Liver Injury', type='Disease', properties={}), Node(id='Nonalcoholic Fatty Liver Disease', type='Disease', properties={}), Node(id='Cirrhosis', type='Disease', properties={}), Node(id='Hepatocellular Carcinoma', type='Disease', properties={}), Node(id='Liver Dysfunction', type='Condition', properties={}), Node(id='Hepatocellular', type='Pathophysiology type', properties={}), Node(id='Cholestasis', type='Pathophysiology type', properties={}), Node(id='Mixed', type='Pathophysiology type', properties={}), Node(id='Alp', type='Enzyme', properties={}), Node(id='Patients With Severe Postoperative Liver Dysfunction', type='Group', properties={}), Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Poorer Prognosis', type='Outcome', properties={}), Node(id='Overall Survival Curves', type='Outcome', properties={}), Node(id='Disease-Free Survival (Dfs) Curves', type='Outcome', properties={}), Node(id='Prognostic Factor', type='Characteristic', properties={}), Node(id='Dfs', type='Outcome', properties={}), Node(id='Radical Resection', type='Procedure', properties={}), Node(id='Stage Iii Colorectal Cancer', type='Disease', properties={})], relationships=[Relationship(source=Node(id='Severe Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Lower Albumin-Bilirubin Scores', type='Score', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Hepatitis Virus Infection', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Alcohol-Induced Liver Injury', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Drug-Induced Liver Injury', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Nonalcoholic Fatty Liver Disease', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Cirrhosis', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Hepatobiliary Enzyme Abnormalities', type='Condition', properties={}), target=Node(id='Hepatocellular Carcinoma', type='Disease', properties={}), type='SEEN_IN', properties={}), Relationship(source=Node(id='Liver Dysfunction', type='Condition', properties={}), target=Node(id='Hepatocellular', type='Pathophysiology type', properties={}), type='CLASSIFIED_INTO', properties={}), Relationship(source=Node(id='Liver Dysfunction', type='Condition', properties={}), target=Node(id='Cholestasis', type='Pathophysiology type', properties={}), type='CLASSIFIED_INTO', properties={}), Relationship(source=Node(id='Liver Dysfunction', type='Condition', properties={}), target=Node(id='Mixed', type='Pathophysiology type', properties={}), type='CLASSIFIED_INTO', properties={}), Relationship(source=Node(id='Alp', type='Enzyme', properties={}), target=Node(id='Patients With Severe Postoperative Liver Dysfunction', type='Group', properties={}), type='HIGHER_IN', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Poorer Prognosi ...
#  GraphDocument(nodes=[Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Dfs', type='Outcome', properties={}), Node(id='Radical Surgery', type='Procedure', properties={}), Node(id='Stage Iii Colorectal Cancer', type='Condition', properties={}), Node(id='Colorectal Cancer', type='Condition', properties={}), Node(id='L/S Ratio', type='Measurement', properties={}), Node(id='Preoperative Ct', type='Procedure', properties={}), Node(id='Postoperative Complications', type='Condition', properties={}), Node(id='Tumor Recurrence', type='Outcome', properties={}), Node(id='Overall Survival', type='Outcome', properties={}), Node(id='Liver Metastasis', type='Condition', properties={}), Node(id='Adjuvant Chemotherapy', type='Treatment', properties={}), Node(id='Fatty Liver', type='Condition', properties={}), Node(id='Adjuvant Chemotherapy Induction Rate', type='Outcome', properties={}), Node(id='Preoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Serum Ast/Alt Ratio', type='Biomarker', properties={}), Node(id='Cirrhosis', type='Condition', properties={}), Node(id='Insulin Resistance', type='Condition', properties={}), Node(id='Alcoholic Liver Disease', type='Condition', properties={}), Node(id='Nafld', type='Condition', properties={}), Node(id='Nash', type='Condition', properties={}), Node(id='Chronic Liver Inflammation', type='Condition', properties={}), Node(id='Albi Score', type='Measurement', properties={}), Node(id='Fib-4 Index', type='Measurement', properties={}), Node(id='Hepatic Stenosis Index', type='Measurement', properties={}), Node(id='Prognosis', type='Outcome', properties={})], relationships=[Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Dfs', type='Outcome', properties={}), type='ASSOCIATED_WITH_WORSENED', properties={}), Relationship(source=Node(id='Radical Surgery', type='Procedure', properties={}), target=Node(id='Stage Iii Colorectal Cancer', type='Condition', properties={}), type='FOR_CONDITION', properties={}), Relationship(source=Node(id='L/S Ratio', type='Measurement', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Preoperative Ct', type='Procedure', properties={}), target=Node(id='L/S Ratio', type='Measurement', properties={}), type='MEASURES', properties={}), Relationship(source=Node(id='Postoperative Complications', type='Condition', properties={}), target=Node(id='Tumor Recurrence', type='Outcome', properties={}), type='INCREASES', properties={}), Relationship(source=Node(id='Postoperative Complications', type='Condition', properties={}), target=Node(id='Overall Survival', type='Outcome', properties={}), type='REDUCES', properties={}), Relationship(source=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Prognosis', type='Outcome', properties={}), type='CONTRIBUTES_TO_POORER', properties={}), Relationship(source=Node(id='Fatty Liver', type='Condition', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='CAUSES', properties={}), Relationship(source=Node(id='Fatty Liver', type='Condition', properties={}), target=Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), type='RISK_FACTOR_FOR', properties={}), Relationship(source=Node(id='Postoperative Complications', type='Condition', properties={}), target=Node(id='Adjuvant Chemotherapy Induction Rate', type='Outcome', properties={}), type='ASSOCIATED_WITH_WORSENED', properties={}), Relationship(source=Node(id='Postoperative Complications', type='Condition', properties={}), target=Node(id='Adjuvant Chemotherapy', type='Treatment', properties={}), type='CAUSES_DELAY_IN', properties={}), Relationship(source=Node(id='Preoperative Liver Dysfunction', type='Condition', properties={}), target=Node(id='Prognosis', ty ...
#  GraphDocument(nodes=[Node(id='Ib-4 Index', type='Index', properties={}), Node(id='Hepatic Stenosis Index', type='Index', properties={}), Node(id='Colorectal Cancer (Crc)', type='Condition', properties={}), Node(id='Unfavorable Prognosis', type='Prognosis', properties={}), Node(id='Chronic Inflammation', type='Condition', properties={}), Node(id='Fatty Liver', type='Condition', properties={}), Node(id='Lifestyle Factors', type='Factor', properties={}), Node(id='Diet', type='Factor', properties={}), Node(id='Exercise', type='Factor', properties={}), Node(id='Preoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Modifiable Risk Factor', type='Risk factor', properties={}), Node(id='Perioperative Liver Dysfunction', type='Condition', properties={}), Node(id='Nafld', type='Condition', properties={}), Node(id='Lifestyle Modification', type='Intervention', properties={}), Node(id='Body Weight', type='Measurement', properties={}), Node(id='Markers Of Fatty Liver', type='Marker', properties={}), Node(id='Liver Function', type='Function', properties={}), Node(id='Sodium-Glucose Cotransporter 2 Inhibitors', type='Drug class', properties={}), Node(id='Type 2 Diabetes Mellitus', type='Condition', properties={}), Node(id='Preoperative Interventions', type='Intervention', properties={}), Node(id='Postoperative Liver Dysfunction', type='Condition', properties={}), Node(id='Prognosis', type='Prognosis', properties={}), Node(id='Study', type='Research', properties={}), Node(id='Retrospective Nature', type='Characteristic', properties={}), Node(id='Single-Center Sample', type='Characteristic', properties={}), Node(id='Limitation', type='Concept', properties={}), Node(id='Large Prospective Cohort Studies', type='Research', properties={}), Node(id='Findings', type='Result', properties={}), Node(id='Clinical Application', type='Application', properties={}), Node(id='Perioperative Factors', type='Factor', properties={}), Node(id='Cambridge English Correction Service', type='Organization', properties={}), Node(id='Manuscript', type='Document', properties={}), Node(id='Kyoto Prefectural University Of Medicine', type='Organization', properties={}), Node(id='Declaration Of Helsinki', type='Document', properties={}), Node(id='Ethical Standards', type='Standard', properties={}), Node(id='Experimental Protocol', type='Protocol', properties={}), Node(id='Ethical Review Board Of The Kyoto Prefectural University Of Medicine', type='Organization', properties={}), Node(id='Erb-C-1178–1', type='Identifier', properties={})], relationships=[Relationship(source=Node(id='Ib-4 Index', type='Index', properties={}), target=Node(id='Fatty Liver', type='Condition', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Hepatic Stenosis Index', type='Index', properties={}), target=Node(id='Fatty Liver', type='Condition', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Colorectal Cancer (Crc)', type='Condition', properties={}), target=Node(id='Unfavorable Prognosis', type='Prognosis', properties={}), type='HAS_PROGNOSIS', properties={}), Relationship(source=Node(id='Unfavorable Prognosis', type='Prognosis', properties={}), target=Node(id='Chronic Inflammation', type='Condition', properties={}), type='ATTRIBUTED_TO', properties={}), Relationship(source=Node(id='Chronic Inflammation', type='Condition', properties={}), target=Node(id='Fatty Liver', type='Condition', properties={}), type='RESULTS_FROM', properties={}), Relationship(source=Node(id='Fatty Liver', type='Condition', properties={}), target=Node(id='Lifestyle Factors', type='Factor', properties={}), type='ASSOCIATED_WITH', properties={}), Relationship(source=Node(id='Lifestyle Factors', type='Factor', properties={}), target=Node(id='Diet', type='Factor', properties={}), type='INCLUDES', properties={}), Relationship(source=Node(id='Lifestyle Factors', type='Factor', properties={}), target=Node(id='Exercise', type='Factor', proper ...
#  GraphDocument(nodes=[Node(id='Shutaro Sumiyoshi', type='Person', properties={}), Node(id='Jun Kiuchi', type='Person', properties={}), Node(id='S-Sumi@Koto.Kpu-M.Ac.Jp', type='Email', properties={}), Node(id='Kiuchi@Koto.Kpu-M.Ac.Jp', type='Email', properties={})], relationships=[Relationship(source=Node(id='Shutaro Sumiyoshi', type='Person', properties={}), target=Node(id='S-Sumi@Koto.Kpu-M.Ac.Jp', type='Email', properties={}), type='HAS_EMAIL', properties={}), Relationship(source=Node(id='Jun Kiuchi', type='Person', properties={}), target=Node(id='Kiuchi@Koto.Kpu-M.Ac.Jp', type='Email', properties={}), type='HAS_EMAIL', properties={})], source=Document(metadata={'id': 'PMC10114433', 'title': 'Postoperative liver dysfunction is associated with poor long-term outcomes in patients with colorectal cancer: a retrospective cohort study - PMC', 'authors': 'Shutaro Sumiyoshi, Jun Kiuchi, Yoshiaki Kuriu, Tomohiro Arita, Hiroki Shimizu, Wataru Takaki, Takuma Ohashi, Yusuke Yamamoto, Hirotaka Konishi, Ryo Morimura, Atsushi Shiozaki, Hisashi Ikoma, Takeshi Kubota, Hitoshi Fujiwara, Kazuma Okamoto, Eigo Otsuji', 'source': 'PMC10114433.json', 'num_authors': 16, 'sections': ['Eigo Otsuji', 'Background', 'Methods', 'Results', 'Conclusions', 'Patients', 'Fig. 1.', 'Risk factor identification and prognostic impact', 'Table 1.', 'Table 2.', 'Table 3.', 'Fig. 2.', 'Table 4.', 'Fatty liver assessment', 'Statistical analysis', 'Clinicopathological factors of postoperative liver dysfunction', 'Risk factors influencing the severity of postoperative liver dysfunction', 'Hepatobiliary enzyme abnormalities', 'Prognostic impact of postoperative liver dysfunction in Stage III CRC', 'Discussion', 'Acknowledgements', 'Availability of data and materials', 'Ethical approval and consent to participate', 'Competing interests', 'Footnotes', 'Contributor Information', 'Associated Data', 'Data Availability Statement'], 'num_sections': 28}, page_content='\nThe authors declare that they have no competing interests.\n\n## Footnotes\nSpringer Nature remains neutral with regard to jurisdictional claims in published maps and institutional affiliations. Shutaro Sumiyoshi and Jun Kiuchi equally contributed to this work.\n\n## Contributor Information\nShutaro Sumiyoshi, Email: s-sumi@koto.kpu-m.ac.jp. Jun Kiuchi, Email: kiuchi@koto.kpu-m.ac.jp.\n\n## Associated Data\nThis section collects any data citations, data availability statements, or supplementary materials included in this article.\n\n## Data Availability Statement\nAll data generated or analyzed during this study are included in this article. Further enquiries can be directed to the corresponding author. Articles from BMC Gastroenterology are provided here courtesy ofBMC'))]

# %%
graph.add_graph_documents(
    graph_documents,
    baseEntityLabel=True,
    include_source=True
)

# %% [markdown]
# # 💾 Step 8: Store Graph in Neo4j
#
# Upload the extracted knowledge graph to Neo4j database.
#
# **Options:**
# - `baseEntityLabel=True` - Add base labels for entity categorization
# - `include_source=True` - Link entities to source documents for traceability

# %%
default_cypher = "MATCH (s)-[r:!MENTIONS]->(t) RETURN s,r,t "

# %%
from neo4j import GraphDatabase
from IPython.display import display
from yfiles_jupyter_graphs import GraphWidget


def showGraph(cypher: str = "MATCH (n)-[r]->(m) RETURN n,r,m LIMIT 20"):
    driver = GraphDatabase.driver(
        uri=neo4j_uri,
        auth=(neo4j_username, neo4j_password)
    )
    with driver.session() as session:
        result = session.run(cypher)
        widget = GraphWidget(graph=result.graph())
        display(widget)

# %% [markdown]
# # 📊 Step 9: Graph Visualization Helper
#
# Create a function to visualize graph data using **yFiles** interactive graph widget.
#
# **Usage:** `showGraph(cypher_query)` - Execute Cypher and display results as an interactive graph.

# %%
from neo4j import GraphDatabase
showGraph()
# Out:
# GraphWidget(layout=Layout(height='710px', width='100%'))

# %% [markdown]
# # 🎨 Step 10: Visualize Full Graph
#
# Display a sample of the knowledge graph (first 20 nodes and relationships).
#
# > 🔍 **Tip:** Click and drag nodes to explore the graph structure interactively!

# %% [markdown]
# # 🧹 Graph Cleanup
#
# Before building a new knowledge graph, we need to clear any existing data in Neo4j to avoid conflicts and duplicates.

# %%
graph.query("MATCH (n) DETACH DELETE n")
print("✓ Cleared existing graph data")
# Out:
# ✓ Cleared existing graph data

# %%
# Query-based Knowledge Graph Extraction and Visualization

def extract_relevant_subgraph(query: str, top_k: int = 5):
    """
    Extract entities and relationships relevant to the user query
    
    Args:
        query: User's natural language query
        top_k: Number of most relevant nodes to return
    
    Returns:
        Cypher query results for visualization
    """
    
    # Use LLM to extract key entities/concepts from the query
    extraction_prompt = f"""
    From this query, extract the main medical/scientific concepts, entities, or keywords:
    Query: "{query}"
    
    Return only a comma-separated list of keywords (no explanation).
    Example: "colorectal cancer, liver dysfunction, prognosis"
    """
    
    response = llm.invoke(extraction_prompt)
    keywords = [k.strip().lower() for k in response.content.split(',')]
    
    print(f"Extracted keywords: {keywords}")
    
    # Build Cypher query to find relevant nodes and relationships
    # Search for nodes whose text contains any of the keywords
    keyword_conditions = " OR ".join([f"toLower(n.id) CONTAINS '{kw}'" for kw in keywords])
    
    cypher_query = f"""
    MATCH (n)
    WHERE {keyword_conditions}
    WITH n LIMIT {top_k}
    MATCH path = (n)-[r]-(connected)
    RETURN n, r, connected
    """
    
    return cypher_query, keywords


def visualize_query_subgraph(query: str, top_k: int = 5):
    """
    Visualize the knowledge graph relevant to the user's query
    """
    print(f"\n🔍 Query: {query}\n")
    
    cypher_query, keywords = extract_relevant_subgraph(query, top_k)
    
    print(f"\n📊 Visualizing subgraph...\n")
    print(f"Cypher query:\n{cypher_query}\n")
    
    # Execute and visualize
    driver = GraphDatabase.driver(
        uri=neo4j_uri,
        auth=(neo4j_username, neo4j_password)
    )
    
    with driver.session() as session:
        result = session.run(cypher_query)
        graph_data = result.graph()
        
        if len(graph_data.nodes) == 0:
            print("⚠️ No relevant entities found for this query.")
            return
        
        print(f"✓ Found {len(graph_data.nodes)} nodes and {len(graph_data.relationships)} relationships")
        
        widget = GraphWidget(graph=graph_data)
        display(widget)
        
    driver.close()

# %% [markdown]
# # 🔍 Step 11: Query-Based Subgraph Extraction
#
# Build an **intelligent query system** that:
#
# 1. 📝 Analyzes user's natural language query
# 2. 🎯 Extracts key medical concepts/entities using LLM
# 3. 🔎 Searches knowledge graph for matching nodes
# 4. 📊 Visualizes relevant subgraph with relationships
#
# **This enables focused exploration of specific topics within the larger knowledge graph.**

# %%
# Example queries - try these!

# Query 1: Liver-related research
visualize_query_subgraph("What research exists about liver dysfunction and cancer?", top_k=10)

# Query 2: Prognosis factors
# visualize_query_subgraph("What are the prognostic factors in colorectal cancer?", top_k=10)

# Query 3: Treatment outcomes
# visualize_query_subgraph("Tell me about postoperative outcomes", top_k=10)

# %% [markdown]
# # 🚀 Step 12: Interactive Query Examples
#
# Try these example queries to explore different aspects of the research:
#
# 1. **Liver dysfunction research** - Disease-specific entities and relationships
# 2. **Prognostic factors** - Outcome predictors and clinical markers
# 3. **Treatment outcomes** - Intervention results and patient outcomes
#
# > 💡 **Tip:** Modify queries or add your own to explore different research angles!
